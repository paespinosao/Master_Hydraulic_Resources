# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import scipy.signal as signal

# %%
lcdata = pd.read_csv (r"C:\Users\USUARIO\TDG_Paula\Batimetria\Detalle\Linea_CostaR_pt.txt",delimiter='\s+',header=None,\
                   names = ['x','y'],encoding =  "ISO-8859-1")

# %%
lcdata
# Out:
#             x         y
# 0   -81.69673  12.58610
# 1   -81.69645  12.58603
# 2   -81.69610  12.58596
# 3   -81.69580  12.58589
# 4   -81.69542  12.58583
# ..        ...       ...
# 675 -81.69056  12.59896
# 676 -81.69064  12.59895
# 677 -81.69065  12.59902
# 678 -81.69071  12.59902
# 679 -81.69073  12.59903
#
# [680 rows x 2 columns]

# %%
x=np.array([float(lcdata.x.values[i]) for i in range(0,len(lcdata.x.values))])
y=np.array([float(lcdata.y.values[i]) for i in range(0,len(lcdata.y.values))])
lc=np.column_stack((x,y))
print(x.shape,y.shape,lc.shape)
# Out:
# (680,) (680,) (680, 2)

# %%
plt.figure(figsize = (15,10))
plt.plot(lc[:,0],lc[:,1])
plt.savefig('Shoreline.pdf',dpi=300,bbox_inches="tight")

# %%
np.savetxt('lineaCosta_Detalle.txt',lc, delimiter = ' ')
